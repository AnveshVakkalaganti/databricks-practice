# %% [markdown]
# #group and aggregate
# before performing the grouping or aggregate
# we want to know <br>
# 1.identifier - high cardinality <br>
# 2.descriptive- name <br>
# 3. metric- avg(age), count(distinct id), max(age) <br>
# 4. measure- age, cid <br>
# 5. grouping- low cardinal values
