# %% [markdown]
# #**Medallion Architecture**

# %%
##it is a layered data design pattern used in the databricks and modern data lakehouses.
## it organizes the data as it moves from raw to cleaned to business-ready, improving the data quality, governance and performance

# %% [markdown]
# #layers
# ##1.bronze -raw
# ##2.silver -filtered
# ##3.gold -business level
