# %% [markdown]
# ##lets learn about bold and italics
# - **bold**
# - *italics*

# %% [markdown]
# #lets learn about colors
# $${\color{red}hello}$$
# $${\color{green}hi}$$

# %% [markdown]
# ##lets learn about embedings
# [click here <-](https://github.com/AnveshVakkalaganti/databricks-practice)

# %% [markdown]
# ##building some tables
# |col1|col2|
# |----|----|
# |a|b|
# |c|d|
