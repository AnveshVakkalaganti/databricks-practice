# %%
dbutils.help()

# %% [markdown]
# we use more of fs utilities down the line which in turn uses the dbfs
# that is databricks file system

# %%
dbutils.fs.cp("source path","destination path")

# %% [markdown]
# ###this is to copy from one path to another
# - dbutils.fs.cp("source path","destination path")
# - dbutils.fs.head("to see the content in the path")
# - dbutil.fs.mkdirs("path with the file or folder that need to be created")
# - dbutil.fs.mv("source","destination")
# #####cut and paste
# - dbutil.fs.put("","",true)
# - dbutil.fs.rm("to remove the file")
